# %%
import pandas as pd
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [14, 20]
# Out:
# /tmp/ipykernel_40402/812510181.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
ll ../Admixture/Regional
# Out:
# total 825488
# -rw-rw-r-- 1 ahenschel    95458 May 31 11:04 admixPlot_yemen_1K.pdf
# -rw-rw-r-- 1 ahenschel   706787 May 31 11:04 admix_Yemen_1K.pdf
# -rw-rw-r-- 1 ahenschel  1388440 May 31 11:04 admix_Yemen_2K.pdf
# -rw-rw-r-- 1 ahenschel  3248999 May 31 11:04 admix_Yemen_3K.pdf
# -rw-rw-r-- 1 ahenschel  4773615 May 31 11:04 admix_Yemen_4K.pdf
# -rw-rw-r-- 1 ahenschel  6453567 May 31 11:04 admix_Yemen_5K.pdf
# -rw-rw-r-- 1 ahenschel   691610 May 31 11:04 admix_Yemen_noOut_1K.pdf
# -rw-rw-r-- 1 ahenschel  5733447 May 31 11:04 admix_Yemen_noOut_1K.svg
# -rw-rw-r-- 1 ahenschel   938331 May 31 11:04 admix_Yemen_noOut_2K.pdf
# -rw-rw-r-- 1 ahenschel  8639557 May 31 11:04 admix_Yemen_noOut_2K.svg
# -rw-rw-r-- 1 ahenschel  2871738 May 31 11:04 admix_Yemen_noOut_3K.pdf
# -rw-rw-r-- 1 ahenschel 24583327 May 31 11:04 admix_Yemen_noOut_3K.svg
# -rw-rw-r-- 1 ahenschel  4446321 May 31 11:04 admix_Yemen_noOut_4K.pdf
# -rw-rw-r-- 1 ahenschel 38379414 May 31 11:04 admix_Yemen_noOut_4K.svg
# ...

# %%
k = 5
base = "yemen_nearby1K_reichH04"
wdir = "../Admixture/Regional"
admix =  "%s/%s.%s.Q" % (wdir, base, k)
famfile = "%s/%s.fam" % (wdir, base) #yemen_nearby1K_reichH04.fam
q = pd.read_csv(admix, header=None, sep=' ')
q.index = [line.split()[1] for line in open(famfile)]

# %%
q
# Out:
#                                             0         1         2         3  \
# EAF4646                              0.034560  0.015932  0.073186  0.873095
# EAF4648                              0.000010  0.000017  0.000010  0.999953
# EAF4644                              0.015267  0.017385  0.058167  0.897163
# EAF4683                              0.005258  0.005388  0.000010  0.981754
# EAF4700                              0.023409  0.009600  0.120443  0.846539
# ...                                       ...       ...       ...       ...
# urn:wtsi:402769_H09_3577STDY6068568  0.043738  0.025488  0.537306  0.386637
# urn:wtsi:402769_H10_3577STDY6068600  0.043592  0.031186  0.684706  0.225765
# urn:wtsi:402769_H11_3577STDY6068625  0.005771  0.015069  0.676915  0.300017
# urn:wtsi:402769_H12_3577STDY6068642  0.064408  0.019058  0.738043  0.156393
# urn:wtsi:402770_A01_3577STDY6068643  0.086783  0.036871  0.663879  0.198235
#
#                                             4
# ...

# %%
q.index = [line.split()[1] for line in open("../MergedDatasets/Yemen/yemen_clean_reichHO4.fam")]
pops = ['Pop%02d'%i for i in range(k)]
q.columns = pops
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 q.index = [line.split()[1] for line in open("../MergedDatasets/Yemen/yemen_clean_reichHO4.fam")]
#       2 pops = ['Pop%02d'%i for i in range(k)]
#       3 q.columns = pops
#
# File ~/miniconda3/envs/admix/lib/python3.9/site-packages/pandas/core/generic.py:5588, in NDFrame.__setattr__(self, name, value)
#    5586 try:
#    5587     object.__getattribute__(self, name)
# -> 5588     return object.__setattr__(self, name, value)
#    5589 except AttributeError:
#    5590     pass
#
# File ~/miniconda3/envs/admix/lib/python3.9/site-packages/pandas/_libs/properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~/miniconda3/envs/admix/lib/python3.9/site-packages/pandas/core/generic.py:769, in NDFrame._set_axis(self, axis, labels)
# ...

# %%
q[:100].plot.bar(stacked=True,width=1)

# %%
q[:100].shape
# Out:
# (100, 12)
