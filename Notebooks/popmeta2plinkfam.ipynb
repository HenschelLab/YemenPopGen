# %% [markdown]
# # Population Info for Plink's fam files
#
# * filling the first columns (family id) with population ids.
# * helps to run Admixtools2 (in R) conveniently (without the need for EIGENSTRAT files, thus no need fixing pop-info into the ind files, fixIndiv)

# %%
import pandas as pd
import numpy as np
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Metadata Tables for NGS data
# Read and prepare NGS metadata tables
#
# * Arabian Peninsula (APPG, Al Marri et al)
# * HGDP NGS (hgdp, bergstrom, Science 2020)
# * Yemen 47 set

# %%
def popfix(pop):
    if pop.startswith('Bantu'): return 'Bantu'
    return pop

yemen = pd.read_excel("../Metadata/Yemen Codes.xlsx", sheet_name="WGS samples").set_index('sid')
hgdpMeta = "../Data/HGDP/HGDPid_populations.csv.gz"
hgdp = pd.read_csv(hgdpMeta).set_index('Id')
hgdp.population = [popfix(pop) for pop in hgdp.population]
hgdp.population.value_counts()
appg = pd.read_csv("../Metadata/appg.meta.csv", sep=' ').set_index('long_ID')

a1 = appg[['population']]
a1.columns = ['Population']
a1.index.name = 'SampleID'

h1 = hgdp[['population']]
h1.columns = ['Population']
h1.index.name = 'SampleID'

y1 = yemen[['region']]
y1.columns = ['Population']
y1.index.name = 'SampleID'

# %%
districts = {'#a0ff00': ["Saada", 'Amran', "Sanaa", 'Dhamar'], 
             '#F39C12': ['Mahwit', 'Hajjah', 'Raymah'], 
             '#229954':['Hadramout', 'Shabwah', 'Al Maharah'],  ## East
             '#A4817A': ['Ibb', 'Taizz'], 
             '#2222FF': ['Jawf', 'Maarib', 'Bayda'], ## North/Desert
             '#E74C3C': ["Al Dhale'e", 'Lahij', 'Abyan', 'Aden'],  ## South/Coast
             '#A0A0A0': ['Hudayda']}  ## West/Coast
districtsR = {}
wgsSamples = {'Lahij': 2, 'Bayda': 2, 'Hudayda': 5}
for k,v in districts.items():
    for gov in v:
        districtsR[gov] = k.lower()
for pop in y1.Population.unique():
    for count in range(wgsSamples.get(pop, 4)):
        print(f'{pop}_{count+1},label,node,#000000,1,bold-italic,{districtsR[pop]}')
# Out:
# Taizz_1,label,node,#000000,1,bold-italic,#a4817a
# Taizz_2,label,node,#000000,1,bold-italic,#a4817a
# Taizz_3,label,node,#000000,1,bold-italic,#a4817a
# Taizz_4,label,node,#000000,1,bold-italic,#a4817a
# Bayda_1,label,node,#000000,1,bold-italic,#2222ff
# Bayda_2,label,node,#000000,1,bold-italic,#2222ff
# Saada_1,label,node,#000000,1,bold-italic,#a0ff00
# Saada_2,label,node,#000000,1,bold-italic,#a0ff00
# Saada_3,label,node,#000000,1,bold-italic,#a0ff00
# Saada_4,label,node,#000000,1,bold-italic,#a0ff00
# Mahwit_1,label,node,#000000,1,bold-italic,#f39c12
# Mahwit_2,label,node,#000000,1,bold-italic,#f39c12
# Mahwit_3,label,node,#000000,1,bold-italic,#f39c12
# Mahwit_4,label,node,#000000,1,bold-italic,#f39c12
# Amran_1,label,node,#000000,1,bold-italic,#a0ff00
# Amran_2,label,node,#000000,1,bold-italic,#a0ff00
# Amran_3,label,node,#000000,1,bold-italic,#a0ff00
# Amran_4,label,node,#000000,1,bold-italic,#a0ff00
# Dhamar_1,label,node,#000000,1,bold-italic,#a0ff00
# Dhamar_2,label,node,#000000,1,bold-italic,#a0ff00
# Dhamar_3,label,node,#000000,1,bold-italic,#a0ff00
# Dhamar_4,label,node,#000000,1,bold-italic,#a0ff00
# Hudayda_1,label,node,#000000,1,bold-italic,#a0a0a0
# Hudayda_2,label,node,#000000,1,bold-italic,#a0a0a0
# Hudayda_3,label,node,#000000,1,bold-italic,#a0a0a0
# Hudayda_4,label,node,#000000,1,bold-italic,#a0a0a0
# Hudayda_5,label,node,#000000,1,bold-italic,#a0a0a0
# Maarib_1,label,node,#000000,1,bold-italic,#2222ff
# Maarib_2,label,node,#000000,1,bold-italic,#2222ff
# Maarib_3,label,node,#000000,1,bold-italic,#2222ff
# Maarib_4,label,node,#000000,1,bold-italic,#2222ff
# Lahij_1,label,node,#000000,1,bold-italic,#e74c3c
# Lahij_2,label,node,#000000,1,bold-italic,#e74c3c
# Hadramout_1,label,node,#000000,1,bold-italic,#229954
# Hadramout_2,label,node,#000000,1,bold-italic,#229954
# Hadramout_3,label,node,#000000,1,bold-italic,#229954
# Hadramout_4,label,node,#000000,1,bold-italic,#229954
# Abyan_1,label,node,#000000,1,bold-italic,#e74c3c
# Abyan_2,label,node,#000000,1,bold-italic,#e74c3c
# Abyan_3,label,node,#000000,1,bold-italic,#e74c3c
# Abyan_4,label,node,#000000,1,bold-italic,#e74c3c
# Ibb_1,label,node,#000000,1,bold-italic,#a4817a
# Ibb_2,label,node,#000000,1,bold-italic,#a4817a
# Ibb_3,label,node,#000000,1,bold-italic,#a4817a
# Ibb_4,label,node,#000000,1,bold-italic,#a4817a

# %%
y1.Population.value_counts()
# Out:
# Hudayda      5
# Taizz        4
# Saada        4
# Mahwit       4
# Amran        4
# Dhamar       4
# Maarib       4
# Hadramout    4
# Abyan        4
# Ibb          4
# Bayda        3
# Lahij        2
# Name: Population, dtype: int64

# %% [markdown]
# ## Metadata Tables for Genotype data
# Read and prepare genotype metadata tables
#
# * Reich AARD (1240K/HO)
# * Our Yemen

# %%
reichset = ['1240K', 'HO'][1]
version=['44.3','50.0'][0]
reich=pd.read_csv(f"../Reich/v{version}_{reichset}_public.anno", sep='\t', encoding='unicode_escape')
reich
# Out:
#    Index Version ID Master ID Publication (or OK to use in a paper)  \
# 0   1798    MAL-005   MAL-005                      SkoglundCell2017
# 1   1799    MAL-009   MAL-009                      SkoglundCell2017
# 2   1800    MAL-011   MAL-011                      SkoglundCell2017
#
#                               Representative contact  \
# 0  Garrett Hellenthal / Saioa Lopez / Mark Thomas...
# 1  Garrett Hellenthal / Saioa Lopez / Mark Thomas...
# 2  Garrett Hellenthal / Saioa Lopez / Mark Thomas...
#
#    Date mean in BP [OxCal mu for a direct radiocarbon date, and average of range for a contextual date]  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#   Full Date: One of two formats. (Format 1) 95.4% CI calibrated radiocarbon age (Conventional Radiocarbon Age BP, Lab number) e.g. 2624-2350 calBCE (3990Â±40 BP, Ua-35016). (Format 2) Archaeological context range, e.g. 2500-1700 BCE  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
#
#     Group Label             Locality Country        Lat.      Long.  \
# 0    Malawi_Yao         Dedza // Yao  Malawi  -14.166667   34.33333
# 1    Malawi_Yao      Machinga // Yao  Malawi  -14.862605  35.574122
# 2  Malawi_Chewa  Mchinga // Chichewa  Malawi  -14.862605  35.574122
#
#   Data source Coverage on autosomal targets  SNPs hit on autosomal targets  \
# 0    Fall2015                            ..                         585645
# 1    Fall2015                            ..                         582189
# 2    Fall2015                            ..                         579844
#
#   Sex  \
# 0   M
# 1   M
# 2   M
#
#   Library type (minus=no.damage.correction, half=damage.retained.at.last.position, plus=damage.fully.corrected, ds=double.stranded.library.preparation, ss=single.stranded.library.preparation)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
#
#   ASSESSMENT (Xcontam interval is listed if lower bound is >0.005, "QUESTIONABLE" if lower bound is 0.01-0.02, "QUESTIONABLE_CRITICAL" or "FAIL" if lower bound is >0.02) (mtcontam confidence interval is listed if coverage >2 and upper bound is <0.98: 0.9-0.95 is "QUESTIONABLE"; <0.9 is "QUESTIONABLE_CRITICAL", questionable status gets overriden by ANGSD with PASS if upper bound of contamination is <0.01 and QUESTIONABLE if upper bound is 0.01-0.05) (damage for ds.half is "QUESTIONABLE_CRITICAL/FAIL" if <0.01, "QUESTIONABLE" for 0.01-0.03, and recorded but passed if 0.03-0.05; libraries with fully-treated last base are "QUESTIONABLE_CRITICAL" or "FAIL" if <0.03, "QUESTIONABLE" if 0.03-0.06, and recorded but passed if 0.06-0.1) (sexratio is QUESTIONABLE if [0.03,0.10] or [0.30,0.35); QUESTIONABLE_CRITICAL/FAIL if (0.10,0.30))
# 0                                  PASS (genotyping)
# 1                                  PASS (genotyping)
# 2                                  PASS (genotyping)

# %%
#print(dict(reich[reich.iloc[:,5]>0]["Group Label"].value_counts()))
ancient='Pakistan_Loebanr_IA','Pakistan_Loebanr_IA','Turkmenistan_Gonur_BA_1','Israel_C','Turkey_N','Turkey_Arslantepe_LateC', \
'Israel_MLBA','Jordan_LBA','Iran_C_TepeHissar','Turkey_CamlibelTarlasi_LateC','Israel_MLBA_lc','Syria_Ebla_EMBA','Iran_GanjDareh_N','Lebanon_IA3.SG','Morocco_Iberomaurusian','Kenya_PastoralN_published', 'Kazakhstan_Central_Saka.SG', 'Jordan_PPNB_published', 'Kenya_PastoralN', 'Iran_HajjiFiruz_C'
for pop in ancient:
    print(f'\\b{pop}\\b')
# Out:
# \bPakistan_Loebanr_IA\b
# \bPakistan_Loebanr_IA\b
# \bTurkmenistan_Gonur_BA_1\b
# \bIsrael_C\b
# \bTurkey_N\b
# \bTurkey_Arslantepe_LateC\b
# \bIsrael_MLBA\b
# \bJordan_LBA\b
# \bIran_C_TepeHissar\b
# \bTurkey_CamlibelTarlasi_LateC\b
# \bIsrael_MLBA_lc\b
# \bSyria_Ebla_EMBA\b
# \bIran_GanjDareh_N\b
# \bLebanon_IA3.SG\b
# \bMorocco_Iberomaurusian\b
# \bKenya_PastoralN_published\b
# \bKazakhstan_Central_Saka.SG\b
# \bJordan_PPNB_published\b
# \bKenya_PastoralN\b
# \bIran_HajjiFiruz_C\b

# %%
reich.Country.value_counts()
# Out:
# Russia             1705
# China              1083
# Spain               680
# Pakistan            633
# Italy               538
#                    ...
# North Macedonia       1
# Crimea                1
# Turkey                1
# Isle of Man           1
# Solomon Islands       1
# Name: Country, Length: 144, dtype: int64

# %%
dict(reich.Country.value_counts())
#    print(kv)
    #print("%-40s: %s"%(k,v))
# Out:
# {'Russia': 642,
#  'China': 567,
#  'Spain': 489,
#  'Italy': 472,
#  'Pakistan': 438,
#  'USA': 434,
#  'Great Britain': 385,
#  'Germany': 356,
#  'Israel': 236,
#  'Nigeria': 236,
#  'India': 229,
#  'France': 198,
#  'Hungary': 195,
#  'Sweden': 193,
#  'Peru': 165,
#  'Kenya': 162,
#  'Turkey': 155,
#  'Kazakhstan': 154,
#  'Japan': 147,
#  'Puerto Rico': 130,
#  'Vietnam': 130,
#  'Dominican Republic': 127,
#  'Gambia': 115,
#  'Finland': 113,
#  'Mongolia': 105,
#  'Sri Lanka': 103,
#  'Colombia': 103,
#  'Poland': 101,
#  'Barbados': 96,
#  'Denmark': 95,
#  'Turkmenistan': 92,
#  'Bangladesh': 88,
#  'Sierra Leone': 87,
#  'Czech Republic': 87,
#  'Estonia': 86,
#  'Ukraine': 83,
#  'Switzerland': 80,
#  'Iran': 68,
#  'Ireland': 63,
#  'Cuba': 58,
#  'Mexico': 58,
#  'China ': 55,
#  'Brazil': 50,
#  'Uzbekistan': 50,
#  'Taiwan': 49,
#  'Bulgaria': 48,
#  'Kyrgyzstan': 47,
#  'Iceland': 46,
#  'Papua New Guinea': 46,
#  'Norway': 45,
#  'Serbia': 45,
#  'Portugal': 40,
#  'Jordan': 39,
#  'Latvia': 38,
#  'Lebanon': 37,
#  'Vanuatu': 34,
#  'Bahamas': 29,
#  'Algeria': 29,
#  'Greece': 29,
#  'Senegal': 26,
#  'Greenland': 24,
#  'Central African Republic': 24,
#  'Armenia': 24,
#  'Chile': 23,
#  'Lithuania': 20,
#  'Tanzania': 20,
#  'Romania': 19,
#  'Argentina': 19,
#  'Canada': 18,
#  'Congo': 18,
#  'Faroes': 17,
#  'Orkney Islands': 17,
#  'Tajikistan': 17,
#  'Croatia': 17,
#  'Syria': 16,
#  'Morocco': 15,
#  'Austria': 14,
#  'South Africa': 14,
#  'Thailand': 13,
#  'Moldova': 13,
#  'Malawi': 12,
#  'St.Lucia': 12,
#  'Namibia': 11,
#  'Cambodia': 11,
#  'Netherlands': 11,
#  'Nepal': 10,
#  'Belgium': 9,
#  'Venezuela': 9,
#  'BotswanaOrNamibia': 8,
#  'Bolivia': 8,
#  'Cameroon': 7,
#  'Malaysia': 6,
#  'DR Congo': 5,
#  'Canary Islands': 5,
#  'Curacao': 5,
#  'Laos': 4,
#  'Guadeloupe': 4,
#  '..': 4,
#  'Botswana': 4,
#  'Gibraltar': 4,
#  'Tonga': 4,
#  'Georgia': 4,
#  'French Polynesia': 3,
#  'Philippines': 3,
#  'Luxembourg': 3,
#  'Myanmar': 3,
#  'Azerbaijan ': 3,
#  'Belize': 3,
#  'Egypt': 3,
#  'Haiti': 2,
#  'Indonesia': 2,
#  'Western Sahara (Morocco)': 2,
#  'Iraq': 2,
#  'Brunei': 2,
#  'Yemen': 2,
#  'Australia': 2,
#  'Montenegro': 2,
#  'South Korea': 2,
#  'Sudan': 1,
#  'Uganda': 1,
#  'Turkey ': 1,
#  'Isle of Man': 1,
#  'Ethiopia': 1,
#  'Angola': 1,
#  'Crimea': 1,
#  'Lesotho': 1,
#  'Slovakia': 1,
#  'Solomon Islands': 1,
#  'New Zealand': 1,
#  'North Macedonia': 1,
#  'Afghanistan': 1,
#  'Albania': 1}

# %%
reich[reich.Country=='Egypt'].iloc[:,10:20]
# Out:
#       Date standard deviation in BP [OxCal sigma for a direct radiocarbon date, and standard deviation of the uniform disribution between the two bounds for a contextual date]  \
# 4568                                                 72
# 4569                                                 43
# 4570                                                 70
#
#      Full Date: One of two formats. (Format 1) 95.4% CI calibrated radiocarbon age (Conventional Radiocarbon Age BP, Lab number) e.g. 2624-2350 calBCE (3990Â±40 BP, Ua-35016). (Format 2) Archaeological context range, e.g. 2500-1700 BCE  \
# 4568           787-546 calBCE (2522Â±24 BP, MAMS-23047)
# 4569    151 calBCE - 23 calCE (2050Â±24 BP, MAMS-23575)
# 4570           779-544 calBCE (2513Â±24 BP, MAMS-23617)
#
#                             GroupID         Locality Country  Lat. Long.  \
# 4568  Egypt_ThirdIntermediatePeriod  Abusir-el Meleq   Egypt  29.9  31.2
# 4569         Egypt_Ptolemaic_contam  Abusir-el Meleq   Egypt  29.9  31.2
# 4570  Egypt_ThirdIntermediatePeriod  Abusir-el Meleq   Egypt  29.9  31.2
#
#      Data source No. Libraries Coverage on autosomal targets
# 4568       1240K            ..                      0.117729
# 4569       1240K            ..                      0.201752
# 4570       1240K            ..                      0.880832

# %%
populationCol = 'GroupID' #'Group Label'
r1 = reich.set_index('Version ID')
r1 = r1[[populationCol]]
r1.columns = ['Population']
r1.index.name = "SampleID"

r1
# Out:
#                                      Population
# SampleID
# I0626_all                         Vietnam_N_all
# I0627_all                         Vietnam_N_all
# I1137_all_published     Vietnam_N_all_published
# I1859_all                         Vietnam_N_all
# I2497_all                        Vietnam_BA_all
# ...                                         ...
# VK94.SG                       Denmark_Viking.SG
# VK95.SG                       Iceland_Viking.SG
# VK98.SG                       Iceland_Viking.SG
# VK99.SG                       Iceland_Viking.SG
# VK9.SG               Greenland_EarlyNorse_o2.SG
#
# [9275 rows x 1 columns]

# %%
import re

coarse = False
df = pd.read_csv("../Metadata/3577stdy_manifest_3450_190315.csv.gz", skiprows=8, sep=',', skip_blank_lines=True)
df1 = df.dropna(subset=['SUPPLIER SAMPLE NAME'])
regions = [re.findall('\D+', sup)[0] for sup in df1['SUPPLIER SAMPLE NAME']]
df1.loc[:,"Population"] = regions
y2 = df1.set_index('SANGER SAMPLE ID')
y2 = y2[['Population']]
y2 = y2[y2.Population!="Empty"]
y2.index.name = 'SampleID'
if coarse: y2.Population = 'Yemen'
y2
# Out:
# /tmp/ipykernel_48989/248209362.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.loc[:,"Population"] = regions
#                 Population
# SampleID
# 3577STDY6068360        Dal
# 3577STDY6068361        Ibb
# 3577STDY6068362        Rsa
# 3577STDY6068363        Rsa
# 3577STDY6068364        Rsa
# ...                    ...
# 3577STDY6068635        Tiz
# 3577STDY6068640        Rsa
# 3577STDY6068641        Ibb
# 3577STDY6068642        Tiz
# 3577STDY6068643        Tiz
#
# [248 rows x 1 columns]

# %%
#a1 = appg[['short_ID', 'population']]
#a1.columns = ['SampleID', 'Population']
#a1 = a1.set_index('SampleID')

#allmeta = pd.concat([y1,h1,a1], axis=0) ## for genotype
allmeta = pd.concat([y2,r1], axis=0)     ## for NGS
allmeta
# Out:
#                                  Population
# SampleID
# 3577STDY6068360                         Dal
# 3577STDY6068361                         Ibb
# 3577STDY6068362                         Rsa
# 3577STDY6068363                         Rsa
# 3577STDY6068364                         Rsa
# ...                                     ...
# VK94.SG                   Denmark_Viking.SG
# VK95.SG                   Iceland_Viking.SG
# VK98.SG                   Iceland_Viking.SG
# VK99.SG                   Iceland_Viking.SG
# VK9.SG           Greenland_EarlyNorse_o2.SG
#
# [9523 rows x 1 columns]

# %%
for k,v in allmeta.Population.value_counts().items():
    print ("%-50s: %s" % (k,v))
# Out:
# Sweden_Viking.SG                                  : 132
# GWD.SG                                            : 112
# YRI.SG                                            : 108
# TSI.SG                                            : 108
# CHS.SG                                            : 106
# GIH.SG                                            : 106
# JPT.SG                                            : 104
# ITU.SG                                            : 103
# IBS.SG                                            : 103
# CHB.SG                                            : 103
# LWK.SG                                            : 101
# PUR.SG                                            : 100
# ESN.SG                                            : 99
# CEU.SG                                            : 99
# CDX.SG                                            : 99
# STU.SG                                            : 99
# KHV.SG                                            : 97
# FIN.SG                                            : 97
# PJL.SG                                            : 96
# CLM.SG                                            : 94
# ACB.SG                                            : 93
# GBR.SG                                            : 92
# BEB.SG                                            : 86
# MSL.SG                                            : 85
# Spain_C                                           : 77
# Denmark_Viking.SG                                 : 71
# PEL.SG                                            : 69
# MXL.SG                                            : 64
# Dominican_LaCaleta_Ceramic                        : 62
# ASW.SG                                            : 60
# Germany_EN_LBK                                    : 54
# Rsa                                               : 48
# France_MN                                         : 43
# Spain_MLN                                         : 42
# Han.SDG                                           : 42
# Palestinian.SDG                                   : 40
# Switzerland_LN                                    : 39
# Germany_BellBeaker                                : 37
# Druze.SDG                                         : 37
# Czech_BellBeaker                                  : 36
# Italy_Imperial.SG                                 : 35
# Russia_MLBA_Sintashta                             : 35
# Spain_EBA                                         : 34
# Estonia_EarlyViking.SG                            : 34
# Taiwan_Hanben_IA                                  : 34
# Israel_MLBA                                       : 32
# Scotland_N                                        : 30
# Germany_Lech_EBA                                  : 30
# Pakistan_Loebanr_IA                               : 29
# Serbia_IronGates_Mesolithic                       : 29
# England_Viking.SG                                 : 29
# Japanese.SDG                                      : 27
# Norway_Viking.SG                                  : 27
# Ireland_MN.SG                                     : 26
# Turkey_Alalakh_MLBA                               : 25
# Ibb                                               : 25
# England_C_EBA                                     : 25
# Russia_Viking.SG                                  : 25
# Hdr                                               : 25
# BedouinB.SDG                                      : 25
# Sardinian.SDG                                     : 25
# French.SDG                                        : 25
# Russian.SDG                                       : 24
# Tiz                                               : 24
# Cuba_CanimarAbajo_Archaic                         : 24
# Iceland_Pre_Christian.SG                          : 23
# India_RoopkundA                                   : 23
# Pathan.SDG                                        : 23
# Burusho.SDG                                       : 22
# Pakistan_Katelai_IA                               : 22
# Russia_Afanasievo                                 : 22
# Brahui.SDG                                        : 22
# Germany_EarlyMedieval.SG                          : 21
# England_N                                         : 21
# Yoruba.SDG                                        : 21
# Kalash.SDG                                        : 21
# Turkmenistan_C_Geoksyur                           : 20
# Mongolia_LBA_Khovsgol_6                           : 20
# Yakut.SDG                                         : 20
# Basque.SDG                                        : 20
# Makrani.SDG                                       : 20
# Mozabite.SDG                                      : 20
# Biaka.SDG                                         : 19
# BedouinA.SDG                                      : 19
# Balochi.SDG                                       : 19
# Turkmenistan_Gonur_BA_1                           : 19
# Italian_North.SDG                                 : 19
# England_BellBeaker                                : 19
# Sindhi_Pakistan.SDG                               : 18
# Italy_Sardinia_EBA                                : 18
# Iceland_Viking.SG                                 : 17
# England_N.SG                                      : 17
# Turkey_Arslantepe_LateC                           : 17
# Jordan_LBA                                        : 17
# Germany_Lech_EBA_lc                               : 17
# Dominican_Atajadizo_Ceramic                       : 17
# Mandenka.SDG                                      : 17
# Turkmenistan_Gonur_BA_1_lc                        : 16
# Kyrgyzstan_TianShan_Hun.SG                        : 16
# Italy_Medieval_EarlyModern.SG                     : 16
# Italy_LA.SG                                       : 16
# Latvia_HG                                         : 16
# Russia_MLBA_Krasnoyarsk                           : 16
# Turkey_N                                          : 16
# Israel_C                                          : 16
# Germany_EN_LBK_published                          : 16
# Mongolia_EIA_Sagly_4                              : 16
# Russia_Ekven_OldBeringSea                         : 15
# Mayan.SDG                                         : 15
# Papuan.DG                                         : 15
# Ukraine_N                                         : 15
# Orcadian.SDG                                      : 15
# Estonia_BA.SG                                     : 14
# Papuan.SDG                                        : 14
# Faroes_EarlyModern.SG                             : 14
# Russia_BA_Okunevo.SG                              : 14
# Portugal_C                                        : 14
# Pima.SDG                                          : 13
# Hazara.SDG                                        : 13
# Poland_Southeast_CordedWare.SG                    : 13
# PEL_SomeAfrican.SG                                : 13
# Mongolia_EIA_SlabGrave_1                          : 13
# Adygei.SDG                                        : 13
# Ukraine_N_published                               : 12
# StLucia_Lavoutte_Ceramic                          : 12
# Pakistan_Udegram_IA                               : 12
# Switzerland_EBA_2                                 : 12
# Dominican_ElSoco_Ceramic                          : 12
# India_RoopkundB                                   : 12
# Hungary_Langobard                                 : 12
# Spain_C_oSteppe                                   : 12
# Italy_Sardinia_N                                  : 12
# USA_CA_Early_SanNicolas.SG                        : 12
# Russia_Srubnaya_Alakul.SG                         : 12
# Russia_MN_Boisman                                 : 11
# Syria_Ebla_EMBA                                   : 11
# Italy_Medieval_EarlyModern_oCentralEuropean.SG    : 11
# Iran_C_TepeHissar                                 : 11
# Karitiana.SDG                                     : 11
# China_SEastAsia_Coastal_LN                        : 11
# Spain_EN                                          : 11
# Hungary_EBA_BellBeaker                            : 11
# Uzbekistan_SappaliTepe_BA                         : 11
# Bulgaria_C                                        : 11
# Russia_Srubnaya                                   : 11
# Germany_CordedWare                                : 11
# Turkey_Ikiztepe_LateC                             : 11
# Nasioi.SDG                                        : 11
# San                                               : 10
# Haj                                               : 10
# Jwf                                               : 10
# Lahj                                              : 10
# Mrb                                               : 10
# Abyn                                              : 10
# France_GrandEst_MN.SG                             : 10
# Hungary_LateC_Baden                               : 10
# USA_CA_Late_SanNicolas.SG                         : 10
# Mhw                                               : 10
# Amr                                               : 10
# Russia_Siberia_Lena_EBA                           : 10
# Germany_SouthernGermany_Singen_EBA                : 10
# Sad                                               : 10
# Dhm                                               : 10
# She.SDG                                           : 10
# Italy_Sardinia_BA_Nuragic                         : 10
# Uyghur.SDG                                        : 10
# Pakistan_H_SaiduSharif                            : 10
# Latvia_BA                                         : 10
# RIA.SG                                            : 10
# RAJ.SG                                            : 10
# ILA.SG                                            : 10
# UBR.SG                                            : 10
# England_MBA                                       : 10
# Czech_EBA                                         : 10
# England_N_all.SG                                  : 10
# Miao.SDG                                          : 10
# Mbuti.SDG                                         : 10
# Russia_Shamanka_Eneolithic.SG                     : 10
# Ireland_Megalithic.SG                             : 10
# Yi.SDG                                            : 10
# Shb                                               : 10
# Germany_Lech_BellBeaker                           : 10
# Tu.SDG                                            : 10
# Uzbekistan_Bustan_BA                              : 10
# Taiwan_Hanben_IA_lc                               : 9
# Italy_Sicily_EBA                                  : 9
# Mongolia_LBA_CenterWest_4                         : 9
# Spain_IA                                          : 9
# VLR.SG                                            : 9
# Tujia.SDG                                         : 9
# Spain_Visigoth_Granada                            : 9
# Oroqen.SDG                                        : 9
# Austria_EN_LBK                                    : 9
# Bahamas_EleutheraIsl_Ceramic                      : 9
# Turkey_CamlibelTarlasi_LateC                      : 9
# Dai.SDG                                           : 9
# Russia_Samara_EBA_Yamnaya                         : 9
# Dal                                               : 9
# Greenland_EarlyNorse.SG                           : 9
# Israel_MLBA_lc                                    : 9
# USA_CA_LSCI.SG                                    : 8
# Italy_N.SG                                        : 8
# Italy_North_EarlyMedieval_Langobards_2            : 8
# Russia_Sarmatian.SG                               : 8
# Spain_Greek_oLocal                                : 8
# Iran_BA1_ShahrISokhta                             : 8
# Cuba_CuevaPerico_Archaic                          : 8
# BIR.SG                                            : 8
# Venezuela_LasLocas_Ceramic                        : 8
# China_Lahu.SDG                                    : 8
# Netherlands_BellBeaker                            : 8
# Kyrgyzstan_TianShan_Saka.SG                       : 8
# Germany_BellBeaker_published                      : 8
# Turkey_N_published                                : 8
# Spain_C.SG                                        : 8
# Iran_GanjDareh_N                                  : 8
# China_YR_MN                                       : 8
# China_Wuzhuangguoliang_LN.EC                      : 8
# Lebanon_IA3.SG                                    : 8
# Cuba_PlayadelMango_Archaic                        : 8
# England_EarlyMedieval_Saxon.SG                    : 8
# Russia_Tagar.SG                                   : 8
# Poland_Viking.SG                                  : 8
# Bahamas_SouthAndros_Ceramic                       : 8
# Naxi.SDG                                          : 8
# Surui.SDG                                         : 8
# Hezhen.SDG                                        : 8
# Dominican_Ceramic_JuanDolio                       : 8
# Daur.SDG                                          : 8
# Spain_Islamic                                     : 8
# Estonia_IA.SG                                     : 7
# Sweden_Motala_HG                                  : 7
# Italy_IA_Republic.SG                              : 7
# Germany_Lech_MBA                                  : 7
# Russia_North_Caucasus                             : 7
# Xibo.SDG                                          : 7
# PuertoRico_PasodelIndio_Ceramic                   : 7
# Switzerland_EBA_1                                 : 7
# Pakistan_Katelai_IA_published                     : 7
# Estonia_Medieval.SG                               : 7
# Russia_UstBelaya_Angara                           : 7
# Cambodian.SDG                                     : 7
# USA_CA_Early_SanNicolas_lc.SG                     : 7
# Czech_CordedWare                                  : 7
# France_GrandEst_EBA.SG                            : 7
# Byd                                               : 7
# Moldova_Glinoe_Scythian.SG                        : 7
# Kenya_PastoralN                                   : 7
# USA_CA_Chumash.SG                                 : 7
# China_YR_LN                                       : 7
# Kazakhstan_Maitan_MLBA_Alakul                     : 7
# Russia_Karasuk_oRISE.SG                           : 6
# Peru_Chincha_LH                                   : 6
# Germany_EarlyMedieval_Alemanic_Byzantine          : 6
# Hungary_MN_ALPc_Tiszadob                          : 6
# Peru_Laramate_900BP                               : 6
# Russia_Kalmykia_EBA_Yamnaya.SG                    : 6
# Hungary_LN_Lengyel                                : 6
# Hungary_MN_ALPc                                   : 6
# Mongola.SDG                                       : 6
# Vietnam_N                                         : 6
# Germany_EarlyMedieval_o1.SG                       : 6
# Germany_EBA_Unetice                               : 6
# Hungary_MN_LBK                                    : 6
# France_Occitanie_IA2.SG                           : 6
# France_GrandEst_IA2.SG                            : 6
# England_IA_Roman.SG                               : 6
# Wales_N.SG                                        : 6
# Kazakhstan_MLBA_OyDzhaylau                        : 6
# Piapoco.SDG                                       : 6
# Mongolia_North_N                                  : 6
# Hungary_Langobard.SG                              : 6
# BantuKenya.SDG                                    : 6
# Poland_BKG.SG                                     : 6
# Morocco_Iberomaurusian                            : 6
# Lithuania_EMN_Narva                               : 6
# Tanzania_PN                                       : 6
# Japan_HG_Jomon                                    : 6
# Portugal_MN.SG                                    : 6
# Italy_Sardinia_C                                  : 6
# Poland_Koszyce_GAC.SG                             : 6
# Russia_Bolshoy                                    : 6
# Sweden_Ansarve_Megalithic.SG                      : 6
# China_Upper_YR_LN                                 : 6
# Spain_C_lc                                        : 6
# Spain_C_published                                 : 6
# ONG.SG                                            : 6
# Uzbekistan_Dzharkutan_BA_1                        : 6
# Denmark_EarlyViking.SG                            : 6
# Ukraine_IA_WesternScythian.SG                     : 6
# Vanuatu_150BP                                     : 6
# Poland_BellBeaker                                 : 6
# Italy_Sardinia_LBA                                : 6
# China_YR_LBIA                                     : 6
# China_Xinjian_IA.SG                               : 6
# France_BellBeaker                                 : 5
# Italy_North_EarlyMedieval_Langobards_1            : 5
# Germany_EarlyMedieval_o3.SG                       : 5
# Hungary_Langobard_o1                              : 5
# Canary_Islands_Guanche.SG                         : 5
# BantuSA.SDG                                       : 5
# China_NEastAsia_Coastal_EN                        : 5
# Russia_Ekven_IA.SG                                : 5
# Scotland_C_EBA                                    : 5
# Armenia_C                                         : 5
# USA_AK_NeoAleut                                   : 5
# Spain_Visigoth_Barcelona                          : 5
# Kazakhstan_Zevakinskiy_LBA                        : 5
# Ignore_Hazara_1.SDG                               : 5
# Turkey_TellKurdu_EC                               : 5
# Turkey_Central_N                                  : 5
# Argentina_ArroyoSeco2_7700BP                      : 5
# Scotland_Viking.SG                                : 5
# Russia_Shamanka_EBA.SG                            : 5
# Italy_LA_oCentralEuropean_o1CentralEuropean.SG    : 5
# Greenland_LateNorse.SG                            : 5
# Russia_EarlySarmatian_SouthernUrals.SG            : 5
# Kazakhstan_MLBA_Aktogai                           : 5
# Spain_Carolingian                                 : 5
# Russia_Late_Sarmatian.SG                          : 5
# Cuba_CuevaEsqueletos_Ceramic                      : 5
# France_GrandEst_IA1.SG                            : 5
# Armenia_LBA.SG                                    : 5
# Italy_Sardinia_LateC                              : 5
# Russia_Viking_o.SG                                : 5
# Italy_Sardinia_IA_Punic_1                         : 5
# Kazakhstan_Central_Saka.SG                        : 5
# Kazakhstan_Medieval_Nomad.SG                      : 5
# Ju_hoan_North.SDG                                 : 5
# Hungary_LN_Sopot                                  : 5
# Spain_EN.SG                                       : 5
# Spain_Roman                                       : 5
# Greece_Peloponnese_N                              : 5
# Hungary_MBA_Vatya.SG                              : 5
# Russia_IA_Ingria.SG                               : 5
# Poland_EBA_Unetice.SG                             : 5
# Hungary_C_Balaton_Lasinja                         : 5
# Denmark_Viking_lc.SG                              : 5
# Russia_Alan.SG                                    : 5
# Mozabite_oSubSaharan.SDG                          : 5
# Sweden_PWC.SG                                     : 5
# Ignore_Sindhi_1.SDG                               : 5
# Dai.DG                                            : 5
# Kenya_PastoralN_published                         : 5
# Lebanon_MBA.SG                                    : 5
# Germany_Lech_MBA_lc                               : 5
# Italy_Sardinia_BA_Nuragic_o                       : 5
# Kazakhstan_MLBA_Kairan                            : 5
# ASW_oNativeAmerican.SG                            : 5
# Kenya_PastoralN_Elmenteitan                       : 5
# Greece_Minoan_Odigitria                           : 5
# Ireland_EN_MN.SG                                  : 5
# Brazil_Sumidouro_10100BP.SG                       : 5
# Iran_C_SehGabi                                    : 5
# Turkey_MLBA.SG                                    : 5
# Poland_Globular_Amphora                           : 5
# Iran_ShahrISokhta_BA2_published                   : 5
# Ireland_LN.SG                                     : 5
# Russia_MBA_Poltavka                               : 5
# Greece_Minoan_Lassithi                            : 5
# England_BellBeaker_lowEEF                         : 5
# Bahamas_AbacoIsl_Ceramic                          : 4
# Vietnam_BA_DongSonCulture.SG                      : 4
# Mandenka.DG                                       : 4
# Norway_IA.SG                                      : 4
# Hungary_IA_Scythian.SG                            : 4
# KHV_o.SG                                          : 4
# France_MN_1                                       : 4
# Turkey_Boncuklu_N.SG                              : 4
# Turkey_Arslantepe_EBA                             : 4
# Kazakhstan_MLBA_KazakhMys                         : 4
# Russia_DevilsCave_N.SG                            : 4
# JAR.SG                                            : 4
# Dominican_Andres_Ceramic                          : 4
# England_LBA                                       : 4
# South_Africa_400BP.SG                             : 4
# France_EN_MN                                      : 4
# Brazil_LapaDoSanto_9600BP                         : 4
# Norway_Medieval.SG                                : 4
# Scotland_N.SG                                     : 4
# Italy_North_EarlyMedieval_Langobards_3            : 4
# Croatia_MN_Sopot                                  : 4
# Spain_Roman_oMixed                                : 4
# Lebanon_Roman.SG                                  : 4
# Balochi_oAfrican.SDG                              : 4
# Russia_Steppe_Catacomb                            : 4
# Spain_NazariPeriod_Muslim                         : 4
# Italy_Sardinia_IA_Punic_2                         : 4
# Scotland_Megalithic.SG                            : 4
# Ireland_EN.SG                                     : 4
# Italy_Sardinia_Medieval                           : 4
# Pakistan_Butkara_IA                               : 4
# China_Upper_YR_IA                                 : 4
# Guadeloupe_AnseGourde_Ceramic                     : 4
# Ignore_Makrani.SDG                                : 4
# Cameroon_SMA_published                            : 4
# Spain_Roman_oLocal                                : 4
# Ireland_Viking.SG                                 : 4
# Italy_Sicily_MN                                   : 4
# Serbia_IronGates_Mesolithic_published             : 4
# Lithuania_BA                                      : 4
# Canada_ASO.SG                                     : 4
# Chile_StraitOfMagellan_Kaweskar_100BP.SG          : 4
# Germany_CordedWare.SG                             : 4
# Ju_hoan_North.DG                                  : 4
# Spain_BA.SG                                       : 4
# Russia_MLBA_Sintashta.SG                          : 4
# Hungary_Maros_EBA.SG                              : 4
# Sweden_Viking_o1.SG                               : 4
# Mexico_Pericues.SG                                : 4
# Jordan_PPNB_published                             : 4
# Russia_Caucasus_Maikop_Novosvobodnaya             : 4
# Russia_UstIda_EBA.SG                              : 4
# Syria_Ebla_EMBA_lc                                : 4
# PUR_oAfrican.SG                                   : 4
# Curacao_deSavaan_Ceramic                          : 4
# Bulgaria_N_published                              : 4
# Spain_Medieval_published                          : 4
# Spain_IA_published                                : 4
# Russia_MLBA_Sintashta_o1                          : 4
# Spain_MLN_published                               : 4
# Turkmenistan_C_Parkhai                            : 4
# Russia_Lokomotiv_Eneolithic.SG                    : 4
# Bahamas_LongIsl_Ceramic                           : 4
# Peru_Lima_LIP_650BP                               : 4
# Denmark_IA.SG                                     : 4
# Lebanon_ERoman.SG                                 : 4
# Brazil_Jabuticabeira2_2000BP                      : 4
# Bolivia_MH_Tiwanaku                               : 4
# Hungary_LateC_EBA_Baden_Yamnaya                   : 4
# Hungary_MN_Vinca                                  : 4
# Scotland_LBA                                      : 4
# Germany_BellBeaker_lc                             : 4
# Ukraine_Mesolithic                                : 4
# Wales_N                                           : 4
# China_Xinjian_IA_o1.SG                            : 4
# Dominican_CuevaJuana_Ceramic                      : 4
# Portugal_MBA.SG                                   : 4
# Nepal_Samdzong_1500BP.SG                          : 4
# Spain_MBA                                         : 4
# Italy_Imperial_o4.SG                              : 4
# Cuba_CuevaCalero_Archaic                          : 4
# Scotland_MBA                                      : 4
# Mbuti.DG                                          : 4
# Turkey_TitrisHoyuk_EBA_lc                         : 4
# Kazakhstan_Kumsay_EBA                             : 4
# Vietnam_N_all                                     : 4
# Buryat.SG                                         : 4
# Scotland_N_mediumlowEEF                           : 4
# Spain_Girona_Visigoth                             : 4
# Hungary_LN_Tisza                                  : 4
# Kyrgyzstan_TianShan_Hun_o.SG                      : 4
# Romania_IronGates_Mesolithic                      : 4
# Italy_Sicily_LBA                                  : 4
# Russia_UstIda_LN.SG                               : 4
# Peru_LIP_La_Galgada_600BP                         : 4
# Uyghur.SG                                         : 3
# Vanuatu_2900BP                                    : 3
# Ignore_BantuKenya.SDG                             : 3
# England_BellBeaker_mediumEEF                      : 3
# Spain_C_published_lc                              : 3
# Pakistan_H_Butkara                                : 3
# MXL_oEuropean.SG                                  : 3
# Italy_C.SG                                        : 3
# Ignore_Palestinian(relative).SDG                  : 3
# Italy_Medieval.SG                                 : 3
# Ignore_Biaka.SDG                                  : 3
# Bulgaria_MalakPreslavets_N                        : 3
# Kazakh.SG                                         : 3
# Karakalpak.SG                                     : 3
# Romania_IronGates_Mesolithic.SG                   : 3
# Uzbek.SG                                          : 3
# Mongolia_LBA_Ulaanzukh_2                          : 3
# Germany_Blatterhohle_MN                           : 3
# Ignore_Mandenka(relative).SDG                     : 3
# Russia_Steppe_Maikop                              : 3
# Germany_Lech_EBA_contam                           : 3
# Pakistan_Barikot_IA                               : 3
# Hazara.SG                                         : 3
# Kazakhstan_MLBA_Dali                              : 3
# Yoruba.DG                                         : 3
# Sweden_BAC.SG                                     : 3
# Tajikistan_Ksirov_Kushan                          : 3
# Russia_Steppe_Eneolithic                          : 3
# Ignore_Adygei.SDG                                 : 3
# PuertoRico_PuntaCandelero_Ceramic                 : 3
# Hungary_Langobard_o2                              : 3
# Pakistan_Loebanr_IA_published                     : 3
# Russia_UstBelaya_Angara.SG                        : 3
# Kazakhstan_Sarmatian.SG                           : 3
# Jordanian.DG                                      : 3
# Punjabi.DG                                        : 3
# Naxi.DG                                           : 3
# Tajik.SG                                          : 3
# England_Mesolithic.SG                             : 3
# Hungary_Langobard_lc                              : 3
# Turkey_EBA.SG                                     : 3
# Kazakhstan_Turk.SG                                : 3
# Scotland_N_published                              : 3
# Italy_Sardinia_EBA_o                              : 3
# Italy_C_BA.SG                                     : 3
# Mongolia_Xiongnu_o1.SG                            : 3
# England_Mesolithic                                : 3
# Switzerland_BellBeaker                            : 3
# Italy_Mesolithic.SG                               : 3
# Chile_CaletaHuelen_MH_1100BP                      : 3
# Palestinian.DG                                    : 3
# Peru_Chanka_LIP                                   : 3
# Hungary_EarlyC_Tiszapolgar                        : 3
# Tajikistan_BA_DashtiKozy                          : 3
# Russia_North_Caucasus_MBA                         : 3
# Iran_HajjiFiruz_C                                 : 3
# French.DG                                         : 3
# Russia_Caucasus_EBA_Yamnaya                       : 3
# Ireland_EBA.SG                                    : 3
# Israel_Ashkelon_IA2                               : 3
# Peru_ElBrujo_EIP_1300BP                           : 3
# Israel_Ashkelon_IA1                               : 3
# Russia_SaltovoMayaki.SG                           : 3
# Romania_IronGates_Mesolithic_published            : 3
# Peru_MH_LIP_Lambayeque                            : 3
# Peru_Highlands_LIP_Chimu                          : 3
# Turkmenistan_C_TepeAnau                           : 3
# Vanuatu_150BP_all                                 : 3
# Israel_Ashkelon_LBA                               : 3
# Dominican_CuevaRoja_Archaic                       : 3
# Hungary_MN_ALPc_Szakalhat                         : 3
# Peru_RioUncallane_1600BP.SG                       : 3
# Ignore_Yakut_1.SDG                                : 3
# Vietnam_LN.SG                                     : 3
# Dominican_LaUnion_Ceramic                         : 3
# Dominican_Macao_Ceramic                           : 3
# Peru_LIP_Ychsma                                   : 3
# Karitiana.DG                                      : 3
# Japan_Jomon.SG                                    : 3
# Turkey_TitrisHoyuk_EBA                            : 3
# China_Shimao_LN                                   : 3
# Spain_NazariPeriod_LateMuslim                     : 3
# Turkey_Ikiztepe                                   : 3
# Sardinian.DG                                      : 3
# Mixe.DG                                           : 3
# Israel_C_published                                : 3
# Mongolia_LBA_MongunTaiga_3                        : 3
# Pakistan_H_Barikot                                : 3
# Russia_Afanasievo.SG                              : 3
# Armenia_EBA                                       : 3
# Finnish.DG                                        : 3
# Serbia_EN                                         : 3
# Uzbekistan_Kokcha_BA                              : 3
# Ukraine_Scythian.SG                               : 3
# Jordan_EBA                                        : 3
# Russia_Uelen_OldBeringSea                         : 3
# Han.DG                                            : 3
# Moldova_Cimmerian.SG                              : 3
# Lebanon_Medieval.SG                               : 3
# Greenland_LateNorse_lc.SG                         : 3
# Poland_Southeast_BellBeaker.SG                    : 3
# Estonia_IA_lc.SG                                  : 3
# Morocco_EN.SG                                     : 3
# Greenland_EarlyNorse_lc.SG                        : 3
# Lebanon_Hellenistic.SG                            : 3
# Germany_MN_Salzmuende                             : 3
# Portugal_LN_C.SG                                  : 3
# Iran_TepeAbdulHosein_N.SG                         : 3
# China_WLR_LN                                      : 3
# China_WLR_MN                                      : 3
# Kazakhstan_Shoendykol_MLBA_Fedorovo               : 3
# Canada_ASO_lc.SG                                  : 3
# Estonia_CordedWare.SG                             : 3
# Vanuatu_2900BP_all                                : 3
# Russia_Siberia_Irkutsk_EBA                        : 3
# USA_CA_Chumash_lc.SG                              : 3
# Gibraltar_EBA                                     : 3
# Greece_BA_Mycenaean                               : 3
# USA_Nevada_LovelockCave_1850BP.SG                 : 3
# Bulgaria_Varna_C                                  : 3
# Germany_Mesolithic                                : 3
# Turkey_N.SG                                       : 3
# Lithuania_LN                                      : 3
# Russia_Khvalynsk_Eneolithic                       : 3
# Italy_Sardinia_C_MonteClaro                       : 3
# France_Occitanie_EBA.SG                           : 3
# Vanuatu_1200BP                                    : 3
# PuertoRico_SantaElena_Ceramic                     : 3
# Sweden_Mesolithic.SG                              : 3
# Germany_MN_Baalberge                              : 3
# China_Miaozigou_MN                                : 3
# Cuba_GuayaboBlanco_Archaic                        : 3
# Spain_Muslim_Zira                                 : 3
# Peru_Lima_EIP_1450BP                              : 3
# Peru_Lauricocha_8600BP                            : 3
# Morocco_LN.SG                                     : 3
# Israel_Natufian_published                         : 3
# Ignore_Basque.SDG                                 : 3
# Russia_Andronovo.SG                               : 3
# Ignore_Brahui.SDG                                 : 3
# Russia_Petrovka                                   : 3
# Finland_Levanluhta                                : 3
# Mayan_o2.SDG                                      : 3
# Mayan_o1.SDG                                      : 3
# Mexico_Pericues.SG_lc                             : 3
# Germany_EarlyMedieval_Alemanic_lc                 : 3
# Pakistan_H_Aligrama                               : 3
# Sweden_Viking_lc.SG                               : 3
# Turkey_EBA                                        : 3
# Poland_CWC_3.SG                                   : 3
# Argentina_BeagleChannel_Yamana_100BP.SG           : 3
# Sweden_BA.SG                                      : 3
# Sweden_LN.SG                                      : 3
# Poland_Ksiaznice_GAC.SG                           : 3
# Japanese.DG                                       : 3
# Russia_Mezhovskaya.SG                             : 3
# Sweden_TRB_MN.SG                                  : 3
# USA_NM_Chaco                                      : 3
# Thailand_IA.SG                                    : 3
# Turkey_TepecikCiftlik_N.SG                        : 3
# Kyrgyzstan_Medieval_Nomad.SG                      : 3
# Mongolia_EBA_Ulgii_1                              : 3
# Armenia_MBA.SG                                    : 3
# Russia_IA_3.SG                                    : 3
# Adygei.DG                                         : 2
# French_Polynesia_200BP                            : 2
# PuertoRico_CanasColloresMonserrate_Ceramic        : 2
# Vanuatu_2200BP                                    : 2
# Bougainville.DG                                   : 2
# Irula.DG                                          : 2
# Scotland_Viking_o.SG                              : 2
# Xibo.DG                                           : 2
# Tanzania_PN_IA_published                          : 2
# STU_o2.SG                                         : 2
# Mongolia_East_N                                   : 2
# Vanuatu_2500BP                                    : 2
# Mayan.DG                                          : 2
# Spanish.DG                                        : 2
# Russia_Kurma_EBA.SG                               : 2
# Poland_CWC_1.SG                                   : 2
# Mozabite.DG                                       : 2
# Kazakhstan_Kangju_o1.SG                           : 2
# Bulgaria_N                                        : 2
# Norway_Mesolithic.SG                              : 2
# Kenya_Kansyore_published                          : 2
# Iran_HajjiFiruz_C_o                               : 2
# Iran_ShahrISokhta_BA2_published_contam            : 2
# Luo.DG                                            : 2
# USA_Ancient_Beringian.SG                          : 2
# Tonga_2500BP                                      : 2
# Kazakhstan_Nomad_HP.SG                            : 2
# Lithuania_Mesolithic                              : 2
# IBS_o2.SG                                         : 2
# Luhya.DG                                          : 2
# Thailand_BA                                       : 2
# Ukraine_Chernyakhiv.SG                            : 2
# Finland_Levanluhta_B_lc                           : 2
# Czech_IA_Hallstatt.SG                             : 2
# Surui.DG                                          : 2
# Botswana_Xaro_EIA                                 : 2
# Malawi_LSA_Hora_8500BP_all                        : 2
# Saami.DG                                          : 2
# IBS_o1.SG                                         : 2
# English.DG                                        : 2
# Jew_Iraqi.DG                                      : 2
# Bolivia_MH_Miraflores                             : 2
# PEL_oHighEuropean.SG                              : 2
# Ireland_Mesolithic.SG                             : 2
# Hazara.DG                                         : 2
# USA_Nevada_SpiritCave_11000BP.SG                  : 2
# ACB_o2.SG                                         : 2
# Turkmenistan_C_Namazga.SG                         : 2
# Spain_Roman_lc                                    : 2
# STU_o1.SG                                         : 2
# Piapoco.DG                                        : 2
# Russia_Chalmny_Varre                              : 2
# Biaka.DG                                          : 2
# Bulgaria_MalakPreslavets_N_published              : 2
# Kalash.DG                                         : 2
# Estonia_EMN_Narva                                 : 2
# England_Viking_o.SG                               : 2
# Burusho.DG                                        : 2
# Ukraine_IA_WesternScythian_o1.SG                  : 2
# BedouinB.DG                                       : 2
# Kenya_EarlyPastoralN                              : 2
# Bahamas_CrookedIsl_Ceramic                        : 2
# Czech_Megalithic.SG                               : 2
# Portugal_C.SG                                     : 2
# Portugal_EBA                                      : 2
# Italy_Sardinia_MBA                                : 2
# Portugal_LBA                                      : 2
# England_Viking_lc.SG                              : 2
# Kazakhstan_His.SG                                 : 2
# Kazakhstan_Nomad_Hun_Sarmatian.SG                 : 2
# Iceland_Early_Christian.SG                        : 2
# Kazakhstan_Wusun.SG                               : 2
# Spain_MLN_published_lc                            : 2
# Cameroon_SMA.SG                                   : 2
# Gambian.DG                                        : 2
# Ulchi.DG                                          : 2
# Poland_ChopiceVeseleCulture                       : 2
# Kyrgyz_Kyrgyzstan.DG                              : 2
# Tubalar.DG                                        : 2
# Russia_Yana_UP.SG                                 : 2
# Armenia_LBA_LchashenMetsamor.SG                   : 2
# Argentina_LagunaChica_6800BP                      : 2
# Portugal_C_lc                                     : 2
# Mongolia_Xiongnu_o2.SG                            : 2
# Russia_Caucasus_LateMaikop                        : 2
# Kazakhstan_Karakhanid.SG                          : 2
# Spain_LBA_published                               : 2
# Poland_Sandomierz_GAC.SG                          : 2
# Kazakhstan_CentralSaka_o2.SG                      : 2
# Scotland_BellBeaker                               : 2
# Estonia_N_CombCeramic.SG                          : 2
# Mende.DG                                          : 2
# Greenland_EarlyNorse_o1.SG                        : 2
# Kazakhstan_Botai_Eneolithic                       : 2
# Scotland_C_EBA_published_lc                       : 2
# China_Lahu.DG                                     : 2
# Kenya_IA_Pastoral                                 : 2
# Vanuatu_1300BP_all                                : 2
# Saharawi.DG                                       : 2
# Spain_Hellenistic_oLocal                          : 2
# Spain_LBA                                         : 2
# Lebanon_Medieval_o2.SG                            : 2
# Spain_Hellenistic_oAegean                         : 2
# Russia_Steppe_Maikop_o                            : 2
# Belize_SakiTzul_7400BP                            : 2
# Mongolia_LBA_CenterWest_5                         : 2
# Spain_HG.SG                                       : 2
# Brazil_LapaDoSanto_9600BP_published               : 2
# Bulgarian.DG                                      : 2
# Kazakhstan_Kangju.SG                              : 2
# Czech_EBA_Unetice                                 : 2
# Czech_EBA_Protounetice                            : 2
# Egypt_ThirdIntermediatePeriod                     : 2
# Russia_Caucasus_Maikop                            : 2
# Uzbekistan_Dzharkutan_BA_2                        : 2
# Czech_N                                           : 2
# Cuba_LasCarolinas_Archaic                         : 2
# Aleut.DG                                          : 2
# Hezhen.DG                                         : 2
# Estonia_BA_lc.SG                                  : 2
# Poland_TRB.SG                                     : 2
# Spain_LN.SG                                       : 2
# Ukraine_Mesolithic_published                      : 2
# China_SEastAsia_Island_LN                         : 2
# Ukraine_Globular_Amphora                          : 2
# Dominican_ElFrances_Ceramic                       : 2
# Kazakhstan_Botai_Eneolithic.SG                    : 2
# Hungary_Langobard_o1.SG                           : 2
# Russia_Caucasus_Eneolithic                        : 2
# Kazakhstan_Nomad_IA.SG                            : 2
# BantuHerero.DG                                    : 2
# Pakistan_Gogdara_IA                               : 2
# USA_AK_Ancient_Athabaskan_1100BP                  : 2
# Croatia_EN_Impressa                               : 2
# Pakistan_Aligrama_IA_published                    : 2
# Jordan_LBA_IA                                     : 2
# China_SEastAsia_Island_EN                         : 2
# Bashkir.SG                                        : 2
# Tajikistan_C_Sarazm                               : 2
# Spain_UP_Azilian                                  : 2
# Yakut.DG                                          : 2
# Spain_IA_lc                                       : 2
# Georgian.DG                                       : 2
# Kinh.DG                                           : 2
# Haiti_Diale1_Ceramic                              : 2
# Brazil_Botocudo.SG                                : 2
# Turkmenistan_Gonur_BA_1_o2                        : 2
# Eskimo_Sireniki.DG                                : 2
# Ignore_French.SDG                                 : 2
# Italy_North_Remedello_C.SG                        : 2
# Switzerland_LN_contam                             : 2
# Ignore_Druze.SDG                                  : 2
# Druze_oAfrican.SDG                                : 2
# Even.DG                                           : 2
# Vietnam_BA_all                                    : 2
# Denmark_LN.SG                                     : 2
# Denmark_BA.SG                                     : 2
# Icelandic.DG                                      : 2
# Tuscan_2.SDG                                      : 2
# Chile_Yamana_BeagleChannel_800BP.SG               : 2
# Hungary_MN_ALPc.SG                                : 2
# Hungary_EN_HG_Koros                               : 2
# Switzerland_EBA_2_contam                          : 2
# France_Alsace_Lingolsheim_MN                      : 2
# Congo_Kindoki_Protohistoric                       : 2
# Thai.DG                                           : 2
# Canada_MDorset.SG                                 : 2
# BantuSA_Herero.SDG                                : 2
# Esan.DG                                           : 2
# Germany_EarlyMedieval_o2.SG                       : 2
# Brahmin.DG                                        : 2
# Quechua.DG                                        : 2
# Jordan_PPNB                                       : 2
# Jordan_PPNB_contam                                : 2
# Madiga.DG                                         : 2
# Igorot.DG                                         : 2
# Ignore_Yakut_2.SDG                                : 2
# Uyghur.DG                                         : 2
# Mongolia_MBA_Munkhkhairkhan_1                     : 2
# Ignore_Burusho.SDG                                : 2
# Hungary_LateC_Baden_published                     : 2
# South_Africa_1900BP.SG                            : 2
# Ignore_Papuan.SDG                                 : 2
# Korean.DG                                         : 2
# Israel_Natufian_contam_published                  : 2
# England_LBA_lowEEF                                : 2
# Hungary_MN_ALPc_Szatmar                           : 2
# Kenya_Kakapel_LIA                                 : 2
# Hungary_EN_Koros_contam                           : 2
# Hungary_MN_ALBK_Szakalhat                         : 2
# Orcadian.DG                                       : 2
# Malawi_LSA_Fingira_6000BP_all_published           : 2
# Ukraine_Eneolithic_Trypillia_published            : 2
# Miao.DG                                           : 2
# Basque.DG                                         : 2
# Spain_Roman_published                             : 2
# Russia_UstBelaya_Angara_published                 : 2
# Israel_MLBA_in.preparation                        : 2
# Mozabite_oEuropean.SDG                            : 2
# Ukraine_Viking.SG                                 : 2
# Balochi.DG                                        : 2
# Vietnam_BA                                        : 2
# Mongolia_EBA_Chemurchek_2                         : 2
# Mongola.DG                                        : 2
# Poland_CWC.SG                                     : 2
# Sweden_FBC.SG                                     : 2
# Makrani.DG                                        : 2
# Italy_Sardinia_Roman                              : 2
# Ignore_Mongola.SDG                                : 2
# Kazakhstan_Mereke_MBA                             : 2
# Argentina_NorthTierradelFiego_Selknam_100BP_lc.SG : 2
# Ireland_N.SG                                      : 2
# Spain_Girona_Visigoth_published                   : 2
# Bengali.DG                                        : 2
# Kazakhstan_IA_Berel_Pazyryk                       : 2
# Russia_IA_EarlySarmatian                          : 2
# Russia_Tuva_IA_AldyBel                            : 2
# Lezgin.DG                                         : 2
# USA_CA_Late_SanNicolas_o.SG                       : 2
# Russia_Potapovka                                  : 2
# France_Occitanie_LN.SG                            : 2
# Yi.DG                                             : 2
# France_NouvelleAquitaine_Mesolithic.SG            : 2
# Armenian.DG                                       : 2
# Estonian.DG                                       : 2
# Tu.DG                                             : 2
# France_Occitanie_EMBA.SG                          : 2
# Israel_MLBA_o                                     : 2
# Russia_Early_Sarmatian.SG                         : 2
# Pima.DG                                           : 2
# France_GrandEst_EN.SG                             : 2
# Tujia.DG                                          : 2
# Bulgaria_BeliBreyag_EBA                           : 2
# France_MN_o                                       : 2
# USA_CA_SanMiguel_IslandChumash.SG                 : 2
# France_EN                                         : 2
# Brazil_Laranjal_6700BP                            : 2
# Russia_Siberia_Lena_EN                            : 2
# Baja_Mexico.SG                                    : 2
# England_IA.SG                                     : 2
# China_AR_Xianbei_IA                               : 2
# Brahui.DG                                         : 2
# China_WLR_BA                                      : 2
# Cretan.DG                                         : 2
# France_Occitanie_MN.SG                            : 2
# Spain_HG                                          : 2
# France_HautsDeFrance_MN.SG                        : 2
# Kyrgyzstan_Aygirdjal_BA                           : 2
# Australian.DG                                     : 2
# USA_AK_PaleoAleut                                 : 2
# USA_AK_PaleoAleut_published                       : 2
# USA_AK_NeoAleut_published                         : 2
# France_BellBeaker_published                       : 2
# Peru_Palpa_LIP_550BP                              : 2
# Peru_SanSebastian_LIP_600BP                       : 2
# China_AR_EN                                       : 2
# China_Wuzhuangguoliang_LN_lc.EC                   : 2
# Russia_MLBA_Sintashta_o2                          : 2
# Turkmenistan_Gonur_BA_2_published                 : 2
# Peru_LimaCoast_MH_1000BP                          : 2
# Malawi_LSA_Hora_8500BP.SG                         : 2
# Hungary_EN_Starcevo_1                             : 2
# Mansi.DG                                          : 2
# Greece_LN_2.SG                                    : 2
# She.DG                                            : 2
# ...
# Gibraltar_EN                                      : 1
# Italy_Sardinia_IA_1                               : 1
# Italy_Sardinia_MBA_published_o                    : 1
# Israel_MLBA_brother.I10359                        : 1
# Dominican_Andres_Archaic                          : 1
# Morocco_Iberomaurusian_sibling.TAF011             : 1
# Malawi_LSA_Hora_8500BP                            : 1
# Tanzania_Zanzibar_1300BP                          : 1
# Russia_MLBA_Sintashta_contam                      : 1
# Thailand_BA_all                                   : 1
# Thailand_LN_BA_lc                                 : 1
# Thailand_BA_lc                                    : 1
# Thailand_IA                                       : 1
# Russia_EHG                                        : 1
# Russia_Alan_o.SG                                  : 1
# Lithuania_Late_Antiquity.SG                       : 1
# Kazakhstan_Kipchak1.SG                            : 1
# Ignore_Palestinian(relative)_o.SDG                : 1
# Ignore_Karitiana(discovery).SDG                   : 1
# Ignore_Yoruba(discovery).SDG                      : 1
# Ignore_Han(discovery).SDG                         : 1
# Ignore_Mbuti(discovery).SDG                       : 1
# Ignore_French(discovery).SDG                      : 1
# Palestinian_o1.SDG                                : 1
# Ignore_BedouinB_2.SDG                             : 1
# Palestinian_o2.SDG                                : 1
# Ignore_Papuan(discovery).SDG                      : 1
# Ignore_BedouinB_1.SDG                             : 1
# Kazakhstan_Nomad_IA_o.SG                          : 1
# Ignore_Sindhi_2.SDG                               : 1
# Ignore_Italian_North.SDG                          : 1
# Ignore_Hazara_2.SDG                               : 1
# Ignore_Russian.SDG                                : 1
# Balochi_oEastAsian.SDG                            : 1
# Ignore_Hezhen.SDG                                 : 1
# Ignore_Daur.SDG                                   : 1
# Ignore_Mongola(discovery).SDG                     : 1
# Ignore_Ju_hoan_North(discovery).SDG               : 1
# Ignore_Sardinian(discovery).SDG                   : 1
# Germany_Roman.SG                                  : 1
# Crimea_Pantikapaion.SG                            : 1
# Germany_EarlyMedieval_o4.SG                       : 1
# USA_CA_Mainland_Chumash_contam_lc.SG              : 1
# USA_CA_SanFranciscoBay.SG                         : 1
# USA_AK_Athabskan.SG                               : 1
# Brazil_Moraes_5800BP                              : 1
# Peru_Cuncaicha_3300BP_contam                      : 1
# Spain_Girona_Visigoth_father.or.son.I12031_published_lc: 1
# Spain_Visigoth_Girona_published                   : 1
# Spain_Medieval_published_lc                       : 1
# Tajikistan_BA_Farkhor_lc                          : 1
# Turkmenistan_BA_Gonur_4                           : 1
# Spain_HG_published                                : 1
# Uzbekistan_Bustan_Eneolithic                      : 1
# Canada_MDorset_published                          : 1
# Italy_Sicily_LBA_son.I3878                        : 1
# Argentina_LagunaChica_1600BP                      : 1
# Israel_MLBA_brother.I10770                        : 1
# Turkey_N.DG                                       : 1
# Serbia_Medieval_Gepidian.SG                       : 1
# Germany_EarlyMedieval.SG_1d.rel.STR355c.SG        : 1
# Ignore_Kalash.SDG                                 : 1
# Ignore_Druze_o.SDG                                : 1
# Ignore_Makrani_o.SDG                              : 1
# Altaian.SG                                        : 1
# Kazakhstan_Kimak.SG                               : 1
# Kyrgyzstan_Turk.SG                                : 1
# Kyrgyzstan_TianShan_Hun.SG_daughter.DA385.SG      : 1
# Kyrgyzstan_TianShan_Saka.SG_brother.DA57.SG       : 1
# Kyrgyzstan_TianShan_Saka_o1.SG                    : 1
# Kyrgyzstan_TianShan_Saka_o2.SG                    : 1
# Kazakhstan_GoldenHordeEuro.SG                     : 1
# Kazakhstan_GoldenHordeAsian.SG                    : 1
# Kazakhstan_Kipchak2.SG                            : 1
# Kazakhstan_Andronovo.SG                           : 1
# Kazakhstan_Karluk_2.SG                            : 1
# Kazakhstan_Wusun_LateSaka_o_mother.I11525.SG      : 1
# Kazakhstan_Karluk_1.SG                            : 1
# Kazakhstan_IA_Saka_dup.I7110.SG                   : 1
# Kazakhstan_Kangju_o3.SG                           : 1
# Kazakhstan_Karakhanid_o_daughter.I12112.SG        : 1
# Kazakhstan_Wusun_LateSaka_dup.I11524.SG           : 1
# Hungary_Medieval.SG                               : 1
# Hungary_IA_Scythian_o.SG                          : 1
# Altaian_o.SG                                      : 1
# Bashkir_o.SG                                      : 1
# Ignore_Piapoco.SDG                                : 1
# Kazakhstan_Botai.SG                               : 1
# Ignore_Pathan.SDG                                 : 1
# BantuSA_Ovambo.SDG                                : 1
# Kazakhstan_EBA_Yamnaya.SG                         : 1
# Tajik_o.SG                                        : 1
# Russia_Sidelkino_HG.SG                            : 1
# Russia_BA_Okunevo_brother.I2078.SG                : 1
# Russia_BA_Okunevo.SG_1d.rel.RISE515.SG            : 1
# Russia_BA_Okunevo_1.or.2d.rel.I3426_dup.I3427.SG  : 1
# Russia_BA_Okunevo_dup.I3426.SG                    : 1
# Russia_BA_Okunevo.SG_sister.RISE672.SG            : 1
# Turkey_IA_o3.SG                                   : 1
# Turkey_IA_o2.SG                                   : 1
# Turkey_Ottoman_2.SG                               : 1
# Turkey_Ottoman_1.SG                               : 1
# Turkmenistan_C_Namazga_o.SG                       : 1
# Turkmenistan_IA.SG                                : 1
# Turkmenistan_C_Namazga_1d.rel.DA380.SG            : 1
# Russia_Kurma_EBA_o.SG                             : 1
# Russia_Shamanka_EBA.SG_brother.DA336.SG           : 1
# Portugal_EBA_lc                                   : 1
# Spain_C_contam                                    : 1
# Latvia_MN_Comb_Ware.SG                            : 1
# Bulgaria_Krepost_N                                : 1
# Greece_Peloponnese_N_all                          : 1
# Hungary_EN_Koros                                  : 1
# Vietnam_N_all_lc                                  : 1
# Austria_Krems1_2_twin.I2483_all                   : 1
# Italy_North_BellBeaker_2                          : 1
# England_C_EBA_highEEF                             : 1
# England_MBA_highEEF                               : 1
# England_BellBeaker_mediumEEF_published            : 1
# Tanzania_Zanzibar_1300BP_all                      : 1
# PUN.SG                                            : 1
# Bulgaria_IA                                       : 1
# BEN.SG                                            : 1
# BIR_o.SG                                          : 1
# Vanuatu_2900BP_published                          : 1
# Ukraine_N_1d.rel.I5881_published                  : 1
# Ukraine_N_1d.rel.I4114_published                  : 1
# Ukraine_N_father.or.son.I5875_published           : 1
# Ukraine_N_brother.I8590_father.or.son.I3718       : 1
# Ukraine_N_father.or.son.I5883_published           : 1
# Ukraine_N_1d.rel.I5870                            : 1
# Tanzania_Luxmanda_3000BP_all                      : 1
# Italy_Sicily_C_o                                  : 1
# Italy_Sicily_BellBeaker_possmisdated_lc           : 1
# Wales_MBA_contam                                  : 1
# Portugal_LN_C                                     : 1
# Germany_BellBeaker_father.or.son.I4132            : 1
# Poland_BellBeaker_father.I6582_father.I6535       : 1
# Poland_EBA                                        : 1
# Poland_BellBeaker_son.I6581_brother.I6582_lc      : 1
# Spain_C_oSteppe_published                         : 1
# Mongolia_EIA_Pazyryk_6                            : 1
# Mongolia_EIA_Xiongnu_7                            : 1
# Mongolia_Chalcolithic_Afanasievo_1_contam         : 1
# Mongolia_Chalcolithic_Afanasievo_1                : 1
# Russia_LBA_Priobrazhenka                          : 1
# Germany_BellBeaker_1d.rel.I6624_published         : 1
# Germany_BellBeaker_1d.rel.I5658_published         : 1
# Scotland_C_EBA_mediumhighEEF_published            : 1
# Scotland_C_EBA_lc                                 : 1
# Greece_N                                          : 1
# Serbia_IronGates_Mesolithic_o_published           : 1
# Serbia_IronGates_N                                : 1
# England_C_EBA_lowEEF                              : 1
# Germany_BellBeaker_father.or.son.I1533            : 1
# Russia_HG_Sosnoviy                                : 1
# Spain_Muslim_Emirate                              : 1
# Kazakhstan_Taldysay_MLBA1                         : 1
# Bulgaria_MalakPreslavets_N_oLowEEF                : 1
# Bulgaria_MalakPreslavets_N_oLowEEF_1d.rel.I1108   : 1
# ASW_oEuropean.SG                                  : 1
# YRI_o.SG                                          : 1
# GWD_oEuropean.SG                                  : 1
# PEL_oHighAfrican.SG                               : 1
# PEL_oEastAsian.SG                                 : 1
# ACB_o1.SG                                         : 1
# PUR_oEuropean.SG                                  : 1
# Kazakhstan_MLBA_Kyzlbulak_o1                      : 1
# Germany_BellBeaker_1d.rel.I5524_lc                : 1
# Kazakhstan_MLBA_Karagash_father.or.son.I4262      : 1
# Latvia_LN_CordedWare                              : 1
# Spain_EBA_1d.rel.I4561                            : 1
# Israel_IBA                                        : 1
# Israel_IA                                         : 1
# Latvia_MN_o2                                      : 1
# Kazakhstan_Kyzlbulak_MLBA1                        : 1
# Uzbekistan_Dzharkutan_BA_1_lc                     : 1
# Latvia_HG_dup.I4632.SG                            : 1
# Bulgaria_EBA_published_contam                     : 1
# Bulgaria_C_oSteppe_published                      : 1
# Bulgaria_MalakPreslavets_N_oHighEEF_published     : 1
# Bulgaria_C_published                              : 1
# Germany_BellBeaker_1d.rel.I5521_lc                : 1
# Czech_BellBeaker_brother.I4888                    : 1
# Kazakhstan_Taldysay_MLBA2                         : 1
# Vanuatu_500BP_published                           : 1
# Serbia_IronGates_Mesolithic_daughter_I5236        : 1
# Serbia_IronGates_Mesolithic_o                     : 1
# Hungary_EN_Koros_o_lc                             : 1
# England_N_published                               : 1
# Czech_BellBeaker_lc                               : 1
# Serbia_EN_Starcevo                                : 1
# Serbia_IronGates_Mesolithic_brother.I4880         : 1
# Croatia_Mesolithic_HG                             : 1
# Afghanistan_DarralKur_MBA                         : 1
# Ukraine_EBA_GlobularAmphora                       : 1
# Peru_Cuncaicha_4200BP                             : 1
# Peru_Cuncaicha_9000BP                             : 1
# Brazil_Jabuticabeira2_2000BP_lc                   : 1
# Israel_C_o2_published                             : 1
# Czech_EBA_Starounetice_dup.I4139                  : 1
# Egypt_Ptolemaic_contam                            : 1
# Romania_C_oHG.SG                                  : 1
# England_Mesolithic_o1                             : 1
# Russia_Sunghir_Medieval.SG                        : 1
# Pakistan_H_SaiduSharif_o2                         : 1
# India_RoopkundB_oNearEast                         : 1
# India_RoopkundC                                   : 1
# Spain_EBA_Africa_published                        : 1
# Spain_Visigoth_Granada_published_contam           : 1
# Argentina_ArroyoSeco2_7400BP_contam               : 1
# Mongolia_EIA_Sagly_4_o_lc                         : 1
# South_Africa_2000BP_lc.SG                         : 1
# South_Africa_2000BP.SG                            : 1
# Russia_Sunghir4.SG                                : 1
# Spain_EBA_lc                                      : 1
# Russia_Sunghir3.SG                                : 1
# Russia_Sunghir2.SG                                : 1
# Russia_Sunghir1.SG                                : 1
# France_Ranchot88_published                        : 1
# France_Chaudardes_published                       : 1
# Germany_Falkenstein_published                     : 1
# Germany_HohleFels49_published                     : 1
# Belgium_UP_GoyetQ376-19_published                 : 1
# Germany_Bockstein_published                       : 1
# Pakistan_Aligrama_IA                              : 1
# Pakistan_Medieval_Singoor                         : 1
# Pakistan_Medieval_Parwak                          : 1
# Iran_GanjDareh_N_father.I1947_father.I1952        : 1
# Spain_Muslim_Almohade_lc                          : 1
# Spain_NazariPeriod_Muslim_published_lc            : 1
# Spain_NazariPeriod_Muslim_o_published             : 1
# Russia_Srubnaya_1d.rel.I0430                      : 1
# Russia_Potapovka_o2                               : 1
# Russia_Srubnaya_1d.rel.I0354                      : 1
# Russia_Srubnaya_o1                                : 1
# Russia_Potapovka_o1                               : 1
# Pakistan_Udegram_IA_father.or.son.I1799_1d.rel.I1992: 1
# Argentina_ArroyoSeco2_7200BP                      : 1
# Spain_EBA_Mallorca                                : 1
# Spain_NazariPeriod_Muslim_published               : 1
# Iran_GanjDareh_N_son.I1946_brother.I1947          : 1
# Russia_MLBA_Sintashta_brother.I1086               : 1
# Russia_MLBA_Sintashta_1d.rel.I1084                : 1
# Russia_MLBA_Sintashta_1d.rel.I1055                : 1
# USA_AK_Ancient_Athabaskan_1100BP_father.or.son.I5319: 1
# Spain_EBA_1d.rel.I4560                            : 1
# Pakistan_Udegram_IA_o                             : 1
# Germany_Brillenhohle_published_lc                 : 1
# Romania_Cioclovina_published_lc                   : 1
# Germany_HohleFels79_published_lc                  : 1
# Belgium_UP_Magdalenian_udg                        : 1
# Mongolia_EIA_2                                    : 1
# Iran_BA_HajjiFiruz                                : 1
# Italy_Sicily_MBA_o2                               : 1
# Croatia_Vucedol                                   : 1
# Ukraine_MBA                                       : 1
# Pakistan_Arkotkila_IA                             : 1
# Pakistan_Loebanr_IA_1d.rel.I12136                 : 1
# Pakistan_Loebanr_IA_son.I6292.son.I10000          : 1
# Pakistan_H_Butkara_mother.I6549                   : 1
# Pakistan_Barikot_IA_o                             : 1
# Jordan_LBA_sibling.I3707                          : 1
# Malawi_LSA_Hora_8500BP_published                  : 1
# England_N_contam                                  : 1
# Wales_Mesolithic                                  : 1
# Jordan_LBA_contam_lc                              : 1
# Turkmenistan_BA_Gonur_3                           : 1
# Turkmenistan_Gonur_BA_1_1d.rel.I1781_lc           : 1
# Kazakhstan_LBA_Tasbas_lc                          : 1
# Ukraine_N_son.I1732                               : 1
# Vanuatu_1300BP                                    : 1
# Belgium_UP_GoyetQ116_1_published                  : 1
# France_LesCloseaux13_published_lc                 : 1
# Iran_C_TepeHissar_lc                              : 1
# Germany_Ofnet_published_lc                        : 1
# Estonia_CordedWare.SG_o2                          : 1
# Russia_MLBA_Priobrazhenka_contam                  : 1
# Turkmenistan_LBA_Sumbar                           : 1
# Turkmenistan_MBA_Parkhai                          : 1
# Turkmenistan_LBA_Parkhai                          : 1
# Turkmenistan_LBA_Parkhai_o                        : 1
# Italy_North_BellBeaker_1                          : 1
# Turkmenistan_EBA_Parkhai                          : 1
# Czech_Baalberge                                   : 1
# USA_NM_Chaco_1d.rel.I5419                         : 1
# USA_NM_Chaco_mother.I2717_mother.I6215.with.different.father.sibling.I5597: 1
# Iran_IA_HajjiFiruz                                : 1
# Tanzania_Luxmanda_3000BP                          : 1
# Belize_MayahakCabPek_9300BP                       : 1
# Austria_Krems1_2_twin.I2483                       : 1
# Russia_MN_Boisman_1d.rel.I1206                    : 1
# France_BellBeaker_NoSteppe                        : 1
# Israel_Natufian_published_contam                  : 1
# Greenland_EarlyNorse_o2.SG                        : 1

# %%
dallmeta = dict(allmeta.Population)

# %%
import os
#famfile = '~/YemenGenomeAnalysis_Unused/WGS/Yemeni.HGDP.APPG.mask.autos.AF_fix_QC.fam'
#famfile = '/home/ahenschel/Dropbox/Yemen/YemenGenomeAnalysis/AdmixTools_HO_mind0.7_geno_0.5_pop10/yemen_reichHO_mind0.7_geno_0.5.LD.QC.fam'

famfile = '/home/ahenschel/Dropbox/Yemen/YemenGenomeAnalysis/AdmixTools_1240K_mind0.5_geno_0.5/yemen_reich1240K_mind0.5_geno_0.5.LD.QC.fam'
fambak = famfile + '_bak'
os.system(f'mv {famfile} {fambak}')
# Out:
# 0

# %%
fam = pd.read_csv(fambak, sep=' ',header=None)
popIds = []
for iid in fam[1]:
    if iid.startswith('urn:wtsi:'): iid = iid.split('_')[-1]

    if iid=='EGAN00001456590': popIds.append('YEMEN')
    elif iid=='longranger222_wgs_27426_APPG7555931_GRCh38_gatk': popIds.append('APPGMISC')
    else: popIds.append(dallmeta[iid])
#    if not iid in dallmeta:
#        print("Not found:", iid)
fam[0] = popIds
fam.to_csv(famfile, header=False, index=False, sep=' ')

# %%
l="""Afghanistan.PZ
Algeria.PZ
Armenia.PZ
Bahrein.PZ
Cyprus.PZ
Iran.PZ
Iraq.PZ
Jordan.PZ
KSA.PZ
Kuwait.PZ
Libya.PZ
Palestine.PZ
Turkey.PZ
Yemen.PZ""".split()
l
# Out:
# ['Afghanistan.PZ', 'Algeria.PZ', 'Armenia.PZ', 'Bahrein.PZ', 'Cyprus.PZ', 'Iran.PZ', 'Iraq.PZ', 'Jordan.PZ', 'KSA.PZ', 'Kuwait.PZ', 'Libya.PZ', 'Palestine.PZ', 'Turkey.PZ', 'Yemen.PZ']

# %%
# %pprint
# Out:
# Pretty printing has been turned OFF
